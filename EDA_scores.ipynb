# %%
import pandas as pd
import numpy as np

# %%
def adjust_fields(scores):
    scores["pos_local"] = scores["pos_local"].fillna(0).astype(int)
    scores["pos_visitante"] = scores["pos_visitante"].fillna(0).astype(int)
    scores["fecha"] = pd.to_datetime(scores["fecha"])
    scores["dia"] = scores["fecha"].dt.dayofweek
    scores["result"] = ""
    for i in range(0, scores.shape[0]):
        if scores["gana_local"][i] == True:
            scores["result"][i] = "Local"
        elif scores["empate"][i] == True:
            scores["result"][i] = "Empate"
        elif scores["gana_visitante"][i] == True:
            scores["result"][i] = "Visitante"
        else:
            scores["result"][i] = np.nan
    scores = scores.sort_values("fecha")
    scores = scores.reset_index(drop=True)
    scores["gol_favor_local_local_6_matches"] = np.nan
    scores["gol_favor_local_visit_6_matches"] = np.nan
    scores["gol_favor_visit_local_6_matches"] = np.nan
    scores["gol_favor_visit_visit_6_matches"] = np.nan

    scores["gol_contra_local_local_6_matches"] = np.nan
    scores["gol_contra_local_visit_6_matches"] = np.nan
    scores["gol_contra_visit_local_6_matches"] = np.nan
    scores["gol_contra_visit_visit_6_matches"] = np.nan

    scores["vict_local_local_6_matches"] = np.nan
    scores["vict_local_visit_6_matches"] = np.nan
    scores["vict_visit_local_6_matches"] = np.nan
    scores["vict_visit_visit_6_matches"] = np.nan

    scores["emp_local_local_6_matches"] = np.nan
    scores["emp_local_visit_6_matches"] = np.nan
    scores["emp_visit_local_6_matches"] = np.nan
    scores["emp_visit_visit_6_matches"] = np.nan

    scores["los_local_local_6_matches"] = np.nan
    scores["los_local_visit_6_matches"] = np.nan
    scores["los_visit_local_6_matches"] = np.nan
    scores["los_visit_visit_6_matches"] = np.nan

    scores["vict_local_igual_6_dire_matches"] = np.nan
    scores["emp_local_igual_6_dire_matches"] = np.nan
    scores["los_local_igual_6_dire_matches"] = np.nan
    scores["vict_local_dif_6_dire_matches"] = np.nan
    scores["emp_local_dif_6_dire_matches"] = np.nan
    scores["los_local_dif_6_dire_matches"] = np.nan

    scores["gol_favor_local_local_3_matches"] = np.nan
    scores["gol_favor_local_visit_3_matches"] = np.nan
    scores["gol_favor_visit_local_3_matches"] = np.nan
    scores["gol_favor_visit_visit_3_matches"] = np.nan

    scores["gol_contra_local_local_3_matches"] = np.nan
    scores["gol_contra_local_visit_3_matches"] = np.nan
    scores["gol_contra_visit_local_3_matches"] = np.nan
    scores["gol_contra_visit_visit_3_matches"] = np.nan

    scores["vict_local_local_3_matches"] = np.nan
    scores["vict_local_visit_3_matches"] = np.nan
    scores["vict_visit_local_3_matches"] = np.nan
    scores["vict_visit_visit_3_matches"] = np.nan

    scores["emp_local_local_3_matches"] = np.nan
    scores["emp_local_visit_3_matches"] = np.nan
    scores["emp_visit_local_3_matches"] = np.nan
    scores["emp_visit_visit_3_matches"] = np.nan

    scores["los_local_local_3_matches"] = np.nan
    scores["los_local_visit_3_matches"] = np.nan
    scores["los_visit_local_3_matches"] = np.nan
    scores["los_visit_visit_3_matches"] = np.nan

    scores["vict_local_igual_3_dire_matches"] = np.nan
    scores["emp_local_igual_3_dire_matches"] = np.nan
    scores["los_local_igual_3_dire_matches"] = np.nan
    scores["vict_local_dif_3_dire_matches"] = np.nan
    scores["emp_local_dif_3_dire_matches"] = np.nan
    scores["los_local_dif_3_dire_matches"] = np.nan

    scores["cuota_local"] = ""
    scores["cuota_empate"] = ""
    scores["cuota_visitante"] = ""

    return scores

# %%
def sliding_filling_for_model(scores):
    for i in range(1, scores.shape[0]):
        scores["gol_favor_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["goles_local"].mean()
        scores["gol_favor_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["goles_visitante"].mean()
        scores["gol_favor_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["goles_local"].mean()
        scores["gol_favor_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["goles_visitante"].mean()

        scores["gol_contra_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["goles_visitante"].mean()
        scores["gol_contra_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["goles_local"].mean()
        scores["gol_contra_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["goles_visitante"].mean()
        scores["gol_contra_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["goles_local"].mean()

        scores["vict_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["gana_local"].mean()
        scores["vict_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["gana_visitante"].mean()
        scores["vict_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["gana_local"].mean()
        scores["vict_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["gana_visitante"].mean()

        scores["emp_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["empate"].mean()
        scores["emp_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["empate"].mean()
        scores["emp_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["empate"].mean()
        scores["emp_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["empate"].mean()

        scores["los_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["gana_visitante"].mean()
        scores["los_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["gana_local"].mean()
        scores["los_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["gana_visitante"].mean()
        scores["los_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["gana_local"].mean()

        scores["vict_local_igual_6_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(6)["gana_local"].mean()
        scores["emp_local_igual_6_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(6)["empate"].mean()
        scores["los_local_igual_6_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(6)["gana_local"].mean()
        scores["vict_local_dif_6_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(6)["gana_visitante"].mean()
        scores["emp_local_dif_6_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(6)["empate"].mean()
        scores["los_local_dif_6_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(6)["gana_visitante"].mean()

        scores["gol_favor_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["goles_local"].mean()
        scores["gol_favor_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["goles_visitante"].mean()
        scores["gol_favor_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["goles_local"].mean()
        scores["gol_favor_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["goles_visitante"].mean()

        scores["gol_contra_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["goles_visitante"].mean()
        scores["gol_contra_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["goles_local"].mean()
        scores["gol_contra_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["goles_visitante"].mean()
        scores["gol_contra_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["goles_local"].mean()

        scores["vict_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["gana_local"].mean()
        scores["vict_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["gana_visitante"].mean()
        scores["vict_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["gana_local"].mean()
        scores["vict_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["gana_visitante"].mean()

        scores["emp_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["empate"].mean()
        scores["emp_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["empate"].mean()
        scores["emp_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["empate"].mean()
        scores["emp_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["empate"].mean()

        scores["los_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["gana_visitante"].mean()
        scores["los_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["gana_local"].mean()
        scores["los_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["gana_visitante"].mean()
        scores["los_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["gana_local"].mean()

        scores["vict_local_igual_3_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(3)["gana_local"].mean()
        scores["emp_local_igual_3_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(3)["empate"].mean()
        scores["los_local_igual_3_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(3)["gana_local"].mean()
        scores["vict_local_dif_3_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(3)["gana_visitante"].mean()
        scores["emp_local_dif_3_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(3)["empate"].mean()
        scores["los_local_dif_3_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(3)["gana_visitante"].mean()

    return scores

# %%
def sliding_filling_for_pred(scores, historical):
    for i in range(1, scores.shape[0]):
        scores["gol_favor_local_local_6_matches"][i] = historical[historical["local"]==scores["local"][i]].tail(6)["goles_local"].mean()
        scores["gol_favor_local_visit_6_matches"][i] = historical[historical["visitante"]==scores["local"][i]].tail(6)["goles_visitante"].mean()
        scores["gol_favor_visit_local_6_matches"][i] = historical[historical["local"]==scores["visitante"][i]].tail(6)["goles_local"].mean()
        scores["gol_favor_visit_visit_6_matches"][i] = historical[historical["visitante"]==scores["visitante"][i]].tail(6)["goles_visitante"].mean()

        scores["gol_contra_local_local_6_matches"][i] = historical[historical["local"]==scores["local"][i]].tail(6)["goles_visitante"].mean()
        scores["gol_contra_local_visit_6_matches"][i] = historical[historical["visitante"]==scores["local"][i]].tail(6)["goles_local"].mean()
        scores["gol_contra_visit_local_6_matches"][i] = historical[historical["local"]==scores["visitante"][i]].tail(6)["goles_visitante"].mean()
        scores["gol_contra_visit_visit_6_matches"][i] = historical[historical["visitante"]==scores["visitante"][i]].tail(6)["goles_local"].mean()

        scores["vict_local_local_6_matches"][i] = historical[historical["local"]==scores["local"][i]].tail(6)["gana_local"].mean()
        scores["vict_local_visit_6_matches"][i] = historical[historical["visitante"]==scores["local"][i]].tail(6)["gana_visitante"].mean()
        scores["vict_visit_local_6_matches"][i] = historical[historical["local"]==scores["visitante"][i]].tail(6)["gana_local"].mean()
        scores["vict_visit_visit_6_matches"][i] = historical[historical["visitante"]==scores["visitante"][i]].tail(6)["gana_visitante"].mean()

        scores["emp_local_local_6_matches"][i] = historical[historical["local"]==scores["local"][i]].tail(6)["empate"].mean()
        scores["emp_local_visit_6_matches"][i] = historical[historical["visitante"]==scores["local"][i]].tail(6)["empate"].mean()
        scores["emp_visit_local_6_matches"][i] = historical[historical["local"]==scores["visitante"][i]].tail(6)["empate"].mean()
        scores["emp_visit_visit_6_matches"][i] = historical[historical["visitante"]==scores["visitante"][i]].tail(6)["empate"].mean()

        scores["los_local_local_6_matches"][i] = historical[historical["local"]==scores["local"][i]].tail(6)["gana_visitante"].mean()
        scores["los_local_visit_6_matches"][i] = historical[historical["visitante"]==scores["local"][i]].tail(6)["gana_local"].mean()
        scores["los_visit_local_6_matches"][i] = historical[historical["local"]==scores["visitante"][i]].tail(6)["gana_visitante"].mean()
        scores["los_visit_visit_6_matches"][i] = historical[historical["visitante"]==scores["visitante"][i]].tail(6)["gana_local"].mean()

        scores["vict_local_igual_6_dire_matches"][i] = historical[(historical["local"]==scores["local"][i])][(historical["visitante"]==scores["visitante"][i])].tail(6)["gana_local"].mean()
        scores["emp_local_igual_6_dire_matches"][i] = historical[(historical["local"]==scores["local"][i])][(historical["visitante"]==scores["visitante"][i])].tail(6)["empate"].mean()
        scores["los_local_igual_6_dire_matches"][i] = historical[(historical["local"]==scores["local"][i])][(historical["visitante"]==scores["visitante"][i])].tail(6)["gana_local"].mean()
        scores["vict_local_dif_6_dire_matches"][i] = historical[(historical["visitante"]==scores["local"][i])][(historical["local"]==scores["visitante"][i])].tail(6)["gana_visitante"].mean()
        scores["emp_local_dif_6_dire_matches"][i] = historical[(historical["visitante"]==scores["local"][i])][(historical["local"]==scores["visitante"][i])].tail(6)["empate"].mean()
        scores["los_local_dif_6_dire_matches"][i] = historical[(historical["visitante"]==scores["local"][i])][(historical["local"]==scores["visitante"][i])].tail(6)["gana_visitante"].mean()

        scores["gol_favor_local_local_3_matches"][i] = historical[historical["local"]==scores["local"][i]].tail(3)["goles_local"].mean()
        scores["gol_favor_local_visit_3_matches"][i] = historical[historical["visitante"]==scores["local"][i]].tail(3)["goles_visitante"].mean()
        scores["gol_favor_visit_local_3_matches"][i] = historical[historical["local"]==scores["visitante"][i]].tail(3)["goles_local"].mean()
        scores["gol_favor_visit_visit_3_matches"][i] = historical[historical["visitante"]==scores["visitante"][i]].tail(3)["goles_visitante"].mean()

        scores["gol_contra_local_local_3_matches"][i] = historical[historical["local"]==scores["local"][i]].tail(3)["goles_visitante"].mean()
        scores["gol_contra_local_visit_3_matches"][i] = historical[historical["visitante"]==scores["local"][i]].tail(3)["goles_local"].mean()
        scores["gol_contra_visit_local_3_matches"][i] = historical[historical["local"]==scores["visitante"][i]].tail(3)["goles_visitante"].mean()
        scores["gol_contra_visit_visit_3_matches"][i] = historical[historical["visitante"]==scores["visitante"][i]].tail(3)["goles_local"].mean()

        scores["vict_local_local_3_matches"][i] = historical[historical["local"]==scores["local"][i]].tail(3)["gana_local"].mean()
        scores["vict_local_visit_3_matches"][i] = historical[historical["visitante"]==scores["local"][i]].tail(3)["gana_visitante"].mean()
        scores["vict_visit_local_3_matches"][i] = historical[historical["local"]==scores["visitante"][i]].tail(3)["gana_local"].mean()
        scores["vict_visit_visit_3_matches"][i] = historical[historical["visitante"]==scores["visitante"][i]].tail(3)["gana_visitante"].mean()

        scores["emp_local_local_3_matches"][i] = historical[historical["local"]==scores["local"][i]].tail(3)["empate"].mean()
        scores["emp_local_visit_3_matches"][i] = historical[historical["visitante"]==scores["local"][i]].tail(3)["empate"].mean()
        scores["emp_visit_local_3_matches"][i] = historical[historical["local"]==scores["visitante"][i]].tail(3)["empate"].mean()
        scores["emp_visit_visit_3_matches"][i] = historical[historical["visitante"]==scores["visitante"][i]].tail(3)["empate"].mean()

        scores["los_local_local_3_matches"][i] = historical[historical["local"]==scores["local"][i]].tail(3)["gana_visitante"].mean()
        scores["los_local_visit_3_matches"][i] = historical[historical["visitante"]==scores["local"][i]].tail(3)["gana_local"].mean()
        scores["los_visit_local_3_matches"][i] = historical[historical["local"]==scores["visitante"][i]].tail(3)["gana_visitante"].mean()
        scores["los_visit_visit_3_matches"][i] = historical[historical["visitante"]==scores["visitante"][i]].tail(3)["gana_local"].mean()

        scores["vict_local_igual_3_dire_matches"][i] = historical[(historical["local"]==scores["local"][i])][(historical["visitante"]==scores["visitante"][i])].tail(3)["gana_local"].mean()
        scores["emp_local_igual_3_dire_matches"][i] = historical[(historical["local"]==scores["local"][i])][(historical["visitante"]==scores["visitante"][i])].tail(3)["empate"].mean()
        scores["los_local_igual_3_dire_matches"][i] = historical[(historical["local"]==scores["local"][i])][(historical["visitante"]==scores["visitante"][i])].tail(3)["gana_local"].mean()
        scores["vict_local_dif_3_dire_matches"][i] = historical[(historical["visitante"]==scores["local"][i])][(historical["local"]==scores["visitante"][i])].tail(3)["gana_visitante"].mean()
        scores["emp_local_dif_3_dire_matches"][i] = historical[(historical["visitante"]==scores["local"][i])][(historical["local"]==scores["visitante"][i])].tail(3)["empate"].mean()
        scores["los_local_dif_3_dire_matches"][i] = historical[(historical["visitante"]==scores["local"][i])][(historical["local"]==scores["visitante"][i])].tail(3)["gana_visitante"].mean()

    return scores

# %%
def fill_cuotas(scores):
    cuotas=pd.read_csv('cuotas_wplay.csv')
    equipos = {'Real Cartagena': 'Real Cartagena', 'Boyacá Chicó': 'Boyaca Chico FC', 'Boyaca Chico FC': 'Boyaca Chico FC', 'Once Caldas': 'Once Caldas', 'Cúcuta Dep.': 'Cúcuta Deportivo',
        'Deportes Tolima': 'Tolima', 'Tolima': 'Tolima', 'Deportivo Pasto': 'Deportivo Pasto', 'Deportivo Cali': 'Deportivo Cali',
        'Millonarios': 'Millonarios', 'Envigado': 'Envigado FC', 'Envigado FC': 'Envigado FC', 'CD La Equidad': 'La Equidad', 'La Equidad': 'La Equidad', 'Quindío': 'Quindío',
        'Indep. Medellín': 'Independiente Medellin', 'Independiente Medellin': 'Independiente Medellin', 'Atlético Huila': 'Atletico Huila', 'Junior FC': 'CD Junior', 'CD Junior': 'CD Junior', 'Pereira': 'Deportivo Pereira', 'Deportivo Pereira': 'Deportivo Pereira',
        'Indep. Santa Fe': 'Independiente Santa Fe', 'Independiente Santa Fe': 'Independiente Santa Fe', 'CD América': 'América de Cali', 'América de Cali': 'América de Cali', 'Atl. Nacional': 'Atlético Nacional', 'Atlético Nacional': 'Atlético Nacional', 'Cortuluá': 'Cortuluá',
        'Itagüí Ditaires': 'Itagüí Ditaires', 'Patriotas': 'Patriotas Boyaca', 'Patriotas Boyaca': 'Patriotas Boyaca', 'Alianza Petrol.': 'Alianza FC', 'Alianza FC': 'Alianza FC', 'Uniautónoma': 'Uniautónoma',
        'Fortaleza FC': 'Fortaleza FC', 'Águilas Pereira': 'Águilas Pereira', 'Jaguares FC': 'Jaguares De Córdoba', 'Jaguares De Córdoba': 'Jaguares De Córdoba',
        'Águilas Doradas': 'Rionegro Aguilas', 'Rionegro Aguilas': 'Rionegro Aguilas', 'Fortaleza CEIF': 'Fortaleza FC', 'A. Bucaramanga': 'Atletico Bucaramanga', 'Atletico Bucaramanga': 'Atletico Bucaramanga', 'Tigres FC': 'Tigres FC',
        'Leones FC': 'Leones FC', 'Union Magdalena': 'Union Magdalena'}

    for i in range(scores.shape[0]):
        scores["local"][i] = equipos.get(scores["local"][i])
        scores["visitante"][i] = equipos.get(scores["visitante"][i])
    cuotas['datetime'] = pd.to_datetime(cuotas['datetime'])
    cuotas = cuotas.sort_values("datetime")
    cuotas["date_lecture"] = ""
    scores['fecha'] = pd.to_datetime(scores['fecha'])
    for i in range(cuotas.shape[0]):
        # cuotas["fecha"][i] = f'{cuotas.iloc[i]["datetime"].year}-{months.get(cuotas.iloc[i]["fecha"].replace("-", " ").split()[1])}-{cuotas.iloc[i]["fecha"].split()[0]}'
        cuotas["date_lecture"][i] = cuotas['datetime'][i].date()
    for i in range(scores.shape[0]):
        if cuotas[(cuotas["date_lecture"] <= scores["fecha"][i]) & (cuotas["local"] == scores["local"][i]) & (cuotas["visitante"] == scores["visitante"][i])].shape[0] >= 1:
            scores.loc[i,"cuota_local"] = cuotas[(cuotas["date_lecture"] <= scores["fecha"][i]) & (cuotas["local"] == scores["local"][i]) & (cuotas["visitante"] == scores["visitante"][i])].iloc[-1]["cuota_local"]
            scores.loc[i,"cuota_visitante"] = cuotas[(cuotas["date_lecture"] <= scores["fecha"][i]) & (cuotas["local"] == scores["local"][i]) & (cuotas["visitante"] == scores["visitante"][i])].iloc[-1]["cuota_visitante"]
            scores.loc[i,"cuota_empate"] = cuotas[(cuotas["date_lecture"] <= scores["fecha"][i]) & (cuotas["local"] == scores["local"][i]) & (cuotas["visitante"] == scores["visitante"][i])].iloc[-1]["cuota_empate"]

    return scores

# %%
def preparations(task_type = "prediction"):
    if task_type == "modeling":
        scores=pd.read_csv("historic_scores.csv")
        adjusted_scores = adjust_fields(scores)
        scores_sliding = sliding_filling_for_model(adjusted_scores)
        complete_scores = fill_cuotas(scores_sliding)
        complete_scores.to_csv("scores_enhanced.csv",index=False)
    elif task_type == "prediction":
        scores = pd.read_csv("future_scores.csv")
        historical = pd.read_csv("historic_scores.csv")
        adjusted_scores = adjust_fields(scores)
        scores_sliding = sliding_filling_for_pred(adjusted_scores, historical)
        complete_scores = fill_cuotas(scores_sliding)        
        complete_scores.to_csv("to_predict.csv",index=False)

# %%
preparations("modeling")
# Out:
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/41981103.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["result"][i] = "Visitante"
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/41981103.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["result"][i] = "Local"
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/41981103.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["result"][i] = "Empate"
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_favor_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_favor_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_favor_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_favor_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_favor_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_favor_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_favor_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_favor_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_contra_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_contra_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_contra_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_contra_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_contra_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_contra_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_contra_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_contra_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:14: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:15: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:19: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:20: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:23: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_local_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:24: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_local_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_visit_local_6_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_visit_visit_6_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:28: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_local_igual_6_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_local_igual_6_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_local_igual_6_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_local_igual_6_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_local_igual_6_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_local_igual_6_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(6)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:31: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_local_dif_6_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_local_dif_6_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:32: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_local_dif_6_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_local_dif_6_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(6)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:33: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_local_dif_6_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_local_dif_6_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(6)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:35: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_favor_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_favor_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:36: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_favor_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_favor_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:37: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_favor_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_favor_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:38: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_favor_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_favor_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:40: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_contra_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_contra_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:41: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_contra_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_contra_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:42: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_contra_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_contra_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["goles_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:43: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["gol_contra_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["gol_contra_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["goles_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:45: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:46: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:47: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:48: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:50: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:51: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:52: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:53: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:55: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_local_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["local"][i]].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:56: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_local_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["local"][i]].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:57: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_visit_local_3_matches"][i] = scores[:i-1][scores["local"]==scores["visitante"][i]].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:58: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_visit_visit_3_matches"][i] = scores[:i-1][scores["visitante"]==scores["visitante"][i]].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:60: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_local_igual_3_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_local_igual_3_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:61: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_local_igual_3_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_local_igual_3_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:62: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_local_igual_3_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_local_igual_3_dire_matches"][i] = scores[:i-1][(scores["local"]==scores["local"][i])][(scores["visitante"]==scores["visitante"][i])].tail(3)["gana_local"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:63: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["vict_local_dif_3_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["vict_local_dif_3_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:64: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["emp_local_dif_3_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["emp_local_dif_3_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(3)["empate"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:65: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   scores["los_local_dif_3_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/1802801993.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["los_local_dif_3_dire_matches"][i] = scores[:i-1][(scores["visitante"]==scores["local"][i])][(scores["local"]==scores["visitante"][i])].tail(3)["gana_visitante"].mean()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/411892506.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["local"][i] = equipos.get(scores["local"][i])
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/411892506.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scores["visitante"][i] = equipos.get(scores["visitante"][i])
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/411892506.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cuotas["date_lecture"][i] = cuotas['datetime'][i].date()
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/411892506.py:24: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   if cuotas[(cuotas["date_lecture"] <= scores["fecha"][i]) & (cuotas["local"] == scores["local"][i]) & (cuotas["visitante"] == scores["visitante"][i])].shape[0] >= 1:
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/411892506.py:25: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   scores.loc[i,"cuota_local"] = cuotas[(cuotas["date_lecture"] <= scores["fecha"][i]) & (cuotas["local"] == scores["local"][i]) & (cuotas["visitante"] == scores["visitante"][i])].iloc[-1]["cuota_local"]
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/411892506.py:26: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   scores.loc[i,"cuota_visitante"] = cuotas[(cuotas["date_lecture"] <= scores["fecha"][i]) & (cuotas["local"] == scores["local"][i]) & (cuotas["visitante"] == scores["visitante"][i])].iloc[-1]["cuota_visitante"]
# /var/folders/g9/q6tzypkx56110bt4s_wsr1y40000gn/T/ipykernel_4971/411892506.py:27: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior. In a future version these will be considered non-comparable. Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   scores.loc[i,"cuota_empate"] = cuotas[(cuotas["date_lecture"] <= scores["fecha"][i]) & (cuotas["local"] == scores["local"][i]) & (cuotas["visitante"] == scores["visitante"][i])].iloc[-1]["cuota_empate"]
